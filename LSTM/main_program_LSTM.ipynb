# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %matplotlib inline

# %%
df_data = pd.read_csv('data/data_raw.csv')

df_data.head()
# Out:
#                                            statement   status
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety

# %%
print(df_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53044 entries, 0 to 53043
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   statement  52681 non-null  object
#  1   status     53042 non-null  object
# dtypes: object(2)
# memory usage: 828.9+ KB
# None

# %%
df_data.shape
# Out:
# (53044, 2)

# %%
# Data kosong
df_data.isnull().sum()
# Out:
# statement    363
# status         2
# dtype: int64

# %%
# Hapus data kosong
df_data.dropna(inplace = True)
df_data.isnull().sum()
# Out:
# statement    0
# status       0
# dtype: int64

# %%
# Cek duplikat data
duplicate_rows = df_data[df_data.duplicated()]
print("cek awal: ", duplicate_rows.shape)

# Hapus data duplikat
df_data = df_data.drop_duplicates()
print("setelah dihapus: ", df_data.shape)
# Out:
# cek awal:  (1592, 2)
# setelah dihapus:  (51088, 2)

# %%
# hapus data >600 karakter
df_data = df_data[df_data['statement'].apply(len) <= 600]

# %%
df_data.shape
# Out:
# (35288, 2)

# %%
plt.figure(figsize=(8,6))

# get the unique status values and their counts
status_counts = df_data['status'].value_counts()

# create the bar plot
ax = status_counts.plot(kind='bar')

# add the count labels on top of each bar
for i, v in enumerate(status_counts):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.title('Distribusi statement berdasarkan status')
plt.xlabel('Status')
plt.ylabel('frekuensi')
plt.tight_layout()
plt.show()

# %%
df_data.head()
# Out:
#                                            statement   status
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety

# %%
# from deep_translator import GoogleTranslator
# from tqdm import tqdm

# # Inisialisasi translator
# translator = GoogleTranslator(source='en', target='id')

# # Fungsi untuk menerjemahkan teks dengan penanganan error
# def translate_text(text):
#     try:
#         return translator.translate(text)
#     except Exception as e:
#         print(f"Error translating text: {text}\nError: {e}")
#         return text  # Kembalikan teks asli jika terjadi error

# # Menggunakan tqdm untuk menampilkan progress bar
# tqdm.pandas()

# # Terapkan fungsi translate ke kolom 'statement'
# df_data['translated_statement'] = df_data['statement'].progress_apply(translate_text)

# df_data.to_csv('data_hasil_translate.csv', index=False)

# df_data.head()

# %%
df_data = pd.read_csv('data/data_hasil_translate.csv')
df_data.head()
# Out:
#                                            statement   status  \
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety
#
#                                 translated_statement
# 0                                           Ya ampun
# 1  susah tidur, pikiran kacau, hati gelisah. Semu...
# 2  Semua salah, mundurlah sayang, maju terus ragu...
# 3  Aku mengalihkan fokusku ke hal lain tapi aku m...
# 4  Aku gelisah dan gelisah, sudah sebulan sekaran...

# %%
df_data['jumlah_kata'] = df_data['translated_statement'].apply(lambda x: len(x.split()))
max_word_count = df_data['jumlah_kata'].max()

print(f"Baris dengan word count tertinggi: {max_word_count}")
# Out:
# Baris dengan word count tertinggi: 133

# %%
# Gabungkan semua teks di kolom 'statement' menjadi satu string
all_words = " ".join(df_data['translated_statement'])

# Tokenisasi dan hitung kata unik
unique_words = set(all_words.split())
unique_word_count = len(unique_words)

# Menampilkan hasil
print(f"Jumlah kata unik: {unique_word_count}")
# Out:
# Jumlah kata unik: 65908

# %%
from nltk.tokenize import word_tokenize
# Tokenisasi
tokenisasi = df_data['translated_statement'].apply(word_tokenize)

# %%
from wordcloud import WordCloud

# Ambil kategori unik dari kolom 'status'
statuses = df_data['status'].unique()

# Tentukan daftar warna untuk WordCloud
colors = ['#FF9999', '#66B2FF', '#99FF99', '#FFCC99', '#FF99CC', '#99CCFF']

# Fungsi untuk menentukan warna
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return random.choice(colors)

# Buat subplots (4 baris x 2 kolom)
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(15, 20))
fig.suptitle('WordCloud for Each Status', fontsize=16)  # Judul utama

# Iterasi untuk setiap status
for i, status in enumerate(statuses):
    # Gabungkan tokenisasi untuk status saat ini
    tokens_data = ' '.join([' '.join(token) for token, label in zip(tokenisasi, df_data['status']) if label == status])

    # Buat WordCloud
    wordcloud = WordCloud(width=800, height=400, background_color='white', color_func=color_func).generate(tokens_data)

    # Tentukan posisi subplot (baris dan kolom)
    row = i // 2  # Baris
    col = i % 2   # Kolom

    # Plot WordCloud ke subplot
    axes[row, col].imshow(wordcloud, interpolation='bilinear')
    axes[row, col].axis('off')  # Matikan axis
    axes[row, col].set_title(f'Status: {status}', fontsize=12)

# Sembunyikan subplot yang tidak terpakai
if len(statuses) % 2 != 0:  # Jika jumlah status ganjil
    axes[-1, -1].axis('off')

# Tampilkan plot
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
df_data.head()
# Out:
#                                            statement   status  \
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety
#
#                                 translated_statement  jumlah_kata
# 0                                           Ya ampun            2
# 1  susah tidur, pikiran kacau, hati gelisah. Semu...            9
# 2  Semua salah, mundurlah sayang, maju terus ragu...           15
# 3  Aku mengalihkan fokusku ke hal lain tapi aku m...           10
# 4  Aku gelisah dan gelisah, sudah sebulan sekaran...           10

# %%
df_data.to_csv('data/data_hasil_EDA.csv', index=False)

# %% [markdown]
# # Pre-Processing

# %%
import numpy as np
import pandas as pd
import stanza
import re
import string

# %%
df_data = pd.read_csv('data/data_hasil_EDA.csv')
# df_data.shape
df_data.head()
# Out:
#                                            statement   status  \
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety
#
#                                 translated_statement  jumlah_kata
# 0                                           Ya ampun            2
# 1  susah tidur, pikiran kacau, hati gelisah. Semu...            9
# 2  Semua salah, mundurlah sayang, maju terus ragu...           15
# 3  Aku mengalihkan fokusku ke hal lain tapi aku m...           10
# 4  Aku gelisah dan gelisah, sudah sebulan sekaran...           10

# %%
vocab_size = 65908
embedding_dim = 50
max_length = 133
trunc_typo = 'post'
padding = 'post'
token_oov = "<OOV>"

# %%
# 0. Cleaning Text
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = text.lower()
    text = str(text).lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'https?://\S+|www\.\S+|\[.*?\]\(.*?\)', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(f'[{re.escape(string.punctuation)}]', '', text)
    text = re.sub(r'\n', ' ', text)
    text = re.sub(r'\w*\d\w*', '', text)
    text = re.sub(r'\s+', ' ', text)

    return text

# %%
# 1. Convert text to lowercase
def to_lower(text):
    return text.lower()

# %%
# 2. Remove stopwords
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

factory = StopWordRemoverFactory()
stop_words = set(factory.get_stop_words())

# List stopword tambahan
manual_stopwords = {"aku", "kamu", "dia", "mereka", "kita", "kami", "mu", "ku", "nya", "itu", "ini", "sini", "situ", "sana", "begitu", "yaitu", "yakni", 
                    "walaupun", "meskipun", "agar", "biar", "supaya", "akan", "telah", "baru", "lagi", "masih", "sekarang", "tadi", "kemarin", "nanti", 
                    "besok", "lalu", "kemudian", "sambil", "serta", "tetapi", "melainkan", "sehingga", "sebab", "karena", "hanya", "saja", "justru", "bahkan", 
                    "memang", "kan", "lah", "pun", "dong", "lho", "kok", "deh", "ya", "nah", "aduh", "oh", "eh", "loh", "seperti", "bagai", "bagaikan", 
                    "umpama", "ibarat", "laksana", "anda", "gua", "elo", "dong", "toh", "lagi", "apalagi", "yang", "untuk", "ke", "dari", "pada", "dengan", 
                    "oleh", "tanpa", "antara", "di", "sebuah", "seorang", "para", "bagi", "atas", "dalam", "namun", "demikian", "juga", "malah", "malahan", 
                    "berikut", "tersebut", "jadi", "adalah", "sebagai", "bukan", "tidak", "iya", "nggak", "ga", "enggak", "sangat", "paling", "amat", "cukup", 
                    "lebih", "kurang", "begitu", "maupun", "apalagi", "misalnya", "sekalipun", "meski", "ketika", "dimana", "siapa", "apa", "kapan", "bagaimana", 
                    "selain", "setelah", "sebelum", "sesudah", "hingga", "selama", "sementara", "sampai", "kemana", "darimana", "kenapa", "mengapa",
                    "wkwk", "haha", "hehe", "hihi", "loh", "yah", "udah", "aja", "banget", "abis", "gitu", "tau", "doang", "nih", "tuh", "kayak", "ngapain", 
                    "nggak", "ngga", "yaudah", "yaelah", "anjay", "anjir", "ciyee", "btw", "cmiiw", "gw", "gua", "gue", "gak", "sih", "loh", "dong", "malah", 
                    "makanya", "kenapa", "ngapain", "apaan", "mau", "ye", "cie", "ciee", "oke", "ok", "sip", "bro", "sis", "mantul", "tapi", "emang", "ya", 
                    "masa", "sumpah", "padahal", "daripada", "udah", "ntar", "yaudah", "bang", "cek", "makasih", "terus", "anj", "kalo", "ntar", "sama", 
                    "soalnya", "jangan", "kek", "kayaknya", "lah", "masih", "eh", "gak", "loh", "kan"
                    }

stop_words.update(manual_stopwords)

# Fungsi untuk menghapus stopword
def remove_stopwords(text):
    words = text.split()
    words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(words)

# %%
# 3. Lemmatization
nlp = stanza.Pipeline('id', processors='tokenize,lemma', use_gpu=False)

# Fungsi lemmatization
def lemmatize_text(text):
    doc = nlp(text)
    sentences = []
    for sentence in doc.sentences:
        lemmas = [word.lemma for word in sentence.words]
        sentences.append(' '.join(lemmas))

    return ' '.join(sentences)
# Out:
# 2024-11-23 07:06:09 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-11-23 07:06:10 INFO: Downloaded file to C:\Users\RafiAchmadfr\stanza_resources\resources.json
# 2024-11-23 07:06:10 WARNING: Language id package default expects mwt, which has been added
# 2024-11-23 07:06:10 INFO: Loading these models for language: id (Indonesian):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | gsd          |
# | mwt       | gsd          |
# | lemma     | gsd_nocharlm |
# ============================
#
# 2024-11-23 07:06:10 INFO: Using device: cpu
# 2024-11-23 07:06:10 INFO: Loading: tokenize
# c:\Users\RafiAchmadfr\AppData\Local\Programs\Python\Python312\Lib\site-packages\stanza\models\tokenization\trainer.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-23 07:06:11 INFO: Loading: mwt
# c:\Users\RafiAchmadfr\AppData\Local\Programs\Python\Python312\Lib\site-packages\stanza\models\mwt\trainer.py:201: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-23 07:06:11 INFO: Loading: lemma
# c:\Users\RafiAchmadfr\AppData\Local\Programs\Python\Python312\Lib\site-packages\stanza\models\lemma\trainer.py:239: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(filename, lambda storage, loc: storage)
# 2024-11-23 07:06:11 INFO: Done loading processors!

# %%
from tqdm.notebook import tqdm

# Fungsi utama preprocessing
def preprocessing_text(df, column_name):
    df = df.copy()
    
    tqdm.pandas(desc="Cleaning Text")
    df[column_name] = df[column_name].progress_apply(clean_text)

    tqdm.pandas(desc="Lowercasing Text")
    df[column_name] = df[column_name].progress_apply(to_lower)

    tqdm.pandas(desc="Removing Stopwords")
    df[column_name] = df[column_name].progress_apply(remove_stopwords)

    tqdm.pandas(desc="Lemmatizing Text")
    df[column_name] = df[column_name].progress_apply(lemmatize_text)

    return df

# %%
# Memanggil fungsi preprocessing
df_data = preprocessing_text(df_data, "translated_statement")
df_data.head()
# Out:
# Cleaning Text:   0%|          | 0/35288 [00:00<?, ?it/s]
# Lowercasing Text:   0%|          | 0/35288 [00:00<?, ?it/s]
# Removing Stopwords:   0%|          | 0/35288 [00:00<?, ?it/s]
# Lemmatizing Text:   0%|          | 0/35288 [00:00<?, ?it/s]
#                                            statement   status  \
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety
#
#                                 translated_statement  jumlah_kata
# 0                                              ampun            2
# 1  susah tidur pikir kacau hati gelisah semua tak...            9
# 2  semua salah mundur lah sayang maju ragu tetapl...           15
# 3                              alih fokusku khawatir           10
# 4                 gelisah gelisah sebul nak maksudmu           10

# %%
# Hapus data kosong
df_data.dropna(inplace = True)
df_data.isnull().sum()
# Out:
# statement               0
# status                  0
# translated_statement    0
# jumlah_kata             0
# dtype: int64

# %%
word_count = df_data['translated_statement'].apply(lambda x: len(x.split()))
max_word_count = word_count.max()

print(f"Baris dengan word count tertinggi: {max_word_count}")
# Out:
# Baris dengan word count tertinggi: 99

# %%
df_data.to_csv('data/data_hasil_prepos.csv', index=False)

# %% [markdown]
# # Pre-Trained Word2Vector

# %%
import pandas as pd
import numpy as np
import h5py

# %%
vocab_size = 65908
embedding_dim = 100
max_sequence_length = 100

# %%
df_data = pd.read_csv('data/data_hasil_prepos.csv')

df_data.head()
# Out:
#                                            statement   status  \
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety
#
#                                 translated_statement  jumlah_kata
# 0                                              ampun            2
# 1  susah tidur pikir kacau hati gelisah semua tak...            9
# 2  semua salah mundur lah sayang maju ragu tetapl...           15
# 3                              alih fokusku khawatir           10
# 4                 gelisah gelisah sebul nak maksudmu           10

# %%
from nltk.tokenize import word_tokenize

df_data['tokenized'] = df_data['translated_statement'].apply(word_tokenize)

# %%
sentences = df_data['tokenized'].tolist()

# %%
# Latih model Word2Vec
from gensim.models import Word2Vec

word2vec_model = Word2Vec(sentences, 
                          vector_size=max_sequence_length, 
                          window=10, 
                          min_count=1, 
                          workers=4)

# %%
# Simpan Word2Vec model
word2vec_model.save("word2vec_model_MentalQ.model")

# Simpan embedding ke file .h5
with h5py.File("word2vec_model_MentalQ.h5", "w") as h5file:
    h5file.create_dataset("vocab", data=word2vec_model.wv.index_to_key, dtype=h5py.string_dtype(encoding='utf-8'))
    h5file.create_dataset("vectors", data=word2vec_model.wv.vectors)

print("Word2Vec model dan embeddings berhasil disimpan ke file .h5.")
# Out:
# Word2Vec model dan embeddings berhasil disimpan ke file .h5.

# %%
# Buat word_index dari Word2Vec
word_index = {word: i + 1 for i, word in enumerate(word2vec_model.wv.index_to_key)}

# Buat embedding matrix
embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    embedding_vector = word2vec_model.wv[word]
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
# === LANGKAH 4: KONVERSI TEKS KE SEQUENCE ===

# Fungsi untuk mengonversi token menjadi indeks
def text_to_sequence(tokens, word_index):
    return [word_index[word] for word in tokens if word in word_index]

# Ubah kolom 'tokenized' menjadi sequence
df_data['sequence'] = df_data['tokenized'].apply(lambda x: text_to_sequence(x, word_index))

# %%
# Padding sequence agar semua memiliki panjang yang sama
from tensorflow.keras.preprocessing.sequence import pad_sequences

padded_sequence = pad_sequences(df_data['sequence'], maxlen=max_sequence_length, padding='post')
print(padded_sequence)
# Out:
# [[1045    0    0 ...    0    0    0]
#  [1208   36   11 ...    0    0    0]
#  [   9   64 1300 ...    0    0    0]
#  ...
#  [  33  187  743 ...    0    0    0]
#  [ 250  273   33 ...    0    0    0]
#  [  47   10  146 ...    0    0    0]]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
status_encoded = label_encoder.fit_transform(df_data['status'])
print(status_encoded)
# Out:
# [0 0 0 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(padded_sequence,
                                                    status_encoded,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    stratify=status_encoded
                                                    )

# %% [markdown]
# # Tunning Hyperparameter

# %%
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Dropout, BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adam

# %%
def create_tuning_model(hp):
    model = Sequential([
        # Embedding Layer
        Embedding(input_dim=len(word_index) + 1, 
                  output_dim=100,
                  weights=[embedding_matrix], 
                  input_length=max_sequence_length, 
                  trainable=hp.Boolean('trainable_embedding', default=False)),  # Embedding trainable atau tidak

        # Bidirectional LSTM
        Bidirectional(LSTM(units=hp.Int('lstm_units', min_value=64, max_value=256, step=32), 
                           kernel_regularizer=l2(hp.Float('l2_regularizer', min_value=0.001, max_value=0.01, step=0.001)),
                           return_sequences=False)),
        Dropout(rate=hp.Float('dropout_rate', min_value=0.2, max_value=0.5, step=0.1)),
        BatchNormalization(),

        # Dense Layers
        Dense(units=hp.Int('dense_units_1', min_value=16, max_value=128, step=16), activation='relu'),
        Dropout(rate=hp.Float('dropout_rate_dense', min_value=0.2, max_value=0.5, step=0.1)),
        BatchNormalization(),

        Dense(units=hp.Int('dense_units_2', min_value=8, max_value=64, step=8), activation='relu'),
        Dropout(rate=hp.Float('dropout_rate_dense', min_value=0.2, max_value=0.5, step=0.1)),
        BatchNormalization(),

        # Output Layer
        Dense(7, activation='softmax')
    ])
    
    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# %%
# Inisialisasi RandomSearch Tuner
tuner = RandomSearch(
    create_tuning_model,
    objective='val_accuracy',  # Target yang ingin dioptimalkan
    max_trials=10,            # Jumlah percobaan model
    executions_per_trial=2,   # Eksekusi ulang setiap model untuk hasil stabil
    directory='keras_tuner_results',
    project_name='mentalQ_tuning'
)

# Menampilkan ruang pencarian hyperparameter
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 8
# trainable_embedding (Boolean)
# {'default': False, 'conditions': []}
# lstm_units (Int)
# {'default': None, 'conditions': [], 'min_value': 64, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# l2_regularizer (Float)
# {'default': 0.001, 'conditions': [], 'min_value': 0.001, 'max_value': 0.01, 'step': 0.001, 'sampling': 'linear'}
# dropout_rate (Float)
# {'default': 0.2, 'conditions': [], 'min_value': 0.2, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# dense_units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 16, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# dropout_rate_dense (Float)
# {'default': 0.2, 'conditions': [], 'min_value': 0.2, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# dense_units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 64, 'step': 8, 'sampling': 'linear'}
# learning_rate (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %%
# Gunakan data training untuk tuning hyperparameter
tuner.search(X_train, y_train,
             epochs=10,           # Epoch lebih kecil untuk tuning awal
             validation_data=(X_test, y_test),
             batch_size=128)
# Out:
# Trial 10 Complete [00h 28m 22s]
# val_accuracy: 0.7358544170856476
#
# Best val_accuracy So Far: 0.7409724295139313
# Total elapsed time: 03h 51m 36s

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
Hyperparameter terbaik:
- LSTM Units: {best_hps.get('lstm_units')}
- Dropout: {best_hps.get('dropout_rate')}
- Dense Units 1: {best_hps.get('dense_units_1')}
- Dense Units 2: {best_hps.get('dense_units_2')}
- Learning Rate: {best_hps.get('learning_rate')}
""")
# Out:
# Hyperparameter terbaik:
# - LSTM Units: 128
# - Dropout: 0.2
# - Dense Units 1: 80
# - Dense Units 2: 32
# - Learning Rate: 0.0015516309595003499

# %% [markdown]
# # Modeling

# %%
def create_model(embedding_dim):
    model = Sequential([
        # Embedding Layer
        Embedding(input_dim=len(word_index) + 1, 
                  output_dim=embedding_dim, 
                  weights=[embedding_matrix], 
                  input_length=max_sequence_length, 
                  trainable=False),

        # Bidirectional LSTM 1
        Bidirectional(LSTM(128, kernel_regularizer=l2(0.01), return_sequences=False)),
        Dropout(0.2),
        BatchNormalization(),

        # Dense Layer 1
        Dense(80, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.2),
        BatchNormalization(),

        # Dense Layer 2
        Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.2),
        BatchNormalization(),

        # Output Layer
        Dense(7, activation='softmax')
    ])
    
    # Compile Model
    model.compile(
        optimizer=Adam(learning_rate=0.0015516309595003499),
        loss='sparse_categorical_crossentropy',  # Gunakan categorical_crossentropy jika label di-one-hot encode
        metrics=['accuracy']
    )
    return model

# %%
model = create_model(embedding_dim)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │     2,791,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ ?                      │   0 (unbuilt) │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,791,500 (10.65 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 2,791,500 (10.65 MB)

# %% [markdown]
# # Train & Evaluasi Model

# %%
num_epochs = 50
batch = 128

history = model.fit(X_train, y_train,
                    epochs = num_epochs,
                    batch_size=batch,
                    validation_data=(X_test, y_test),
                    )
# Out:
# Epoch 1/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 81s 349ms/step - accuracy: 0.5434 - loss: 3.7289 - val_accuracy: 0.6299 - val_loss: 1.4821
# Epoch 2/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 75s 341ms/step - accuracy: 0.6686 - loss: 1.2191 - val_accuracy: 0.6749 - val_loss: 1.0408
# Epoch 3/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 77s 349ms/step - accuracy: 0.6852 - loss: 0.9974 - val_accuracy: 0.6918 - val_loss: 0.9790
# Epoch 4/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 79s 361ms/step - accuracy: 0.6891 - loss: 0.9513 - val_accuracy: 0.6828 - val_loss: 0.9744
# Epoch 5/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 355ms/step - accuracy: 0.6949 - loss: 0.9446 - val_accuracy: 0.6844 - val_loss: 0.9456
# Epoch 6/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 79s 361ms/step - accuracy: 0.6962 - loss: 0.9228 - val_accuracy: 0.6958 - val_loss: 0.8989
# Epoch 7/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 355ms/step - accuracy: 0.7040 - loss: 0.8999 - val_accuracy: 0.7037 - val_loss: 0.8794
# Epoch 8/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 80s 361ms/step - accuracy: 0.7001 - loss: 0.9123 - val_accuracy: 0.6844 - val_loss: 0.9494
# Epoch 9/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 355ms/step - accuracy: 0.7029 - loss: 0.8961 - val_accuracy: 0.7012 - val_loss: 0.8896
# Epoch 10/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 79s 359ms/step - accuracy: 0.7060 - loss: 0.8832 - val_accuracy: 0.7024 - val_loss: 0.9103
# Epoch 11/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 81s 367ms/step - accuracy: 0.7066 - loss: 0.8985 - val_accuracy: 0.7040 - val_loss: 0.8737
# Epoch 12/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 79s 357ms/step - accuracy: 0.7081 - loss: 0.8901 - val_accuracy: 0.7037 - val_loss: 0.8951
# Epoch 13/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 79s 360ms/step - accuracy: 0.7036 - loss: 0.8929 - val_accuracy: 0.7094 - val_loss: 0.8541
# Epoch 14/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 353ms/step - accuracy: 0.7098 - loss: 0.8864 - val_accuracy: 0.7120 - val_loss: 0.8719
# Epoch 15/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 77s 352ms/step - accuracy: 0.7080 - loss: 0.8917 - val_accuracy: 0.6978 - val_loss: 0.9010
# Epoch 16/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 80s 364ms/step - accuracy: 0.7111 - loss: 0.8819 - val_accuracy: 0.7086 - val_loss: 0.8863
# Epoch 17/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 76s 347ms/step - accuracy: 0.7185 - loss: 0.8710 - val_accuracy: 0.7059 - val_loss: 0.8700
# Epoch 18/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 79s 359ms/step - accuracy: 0.7102 - loss: 0.8740 - val_accuracy: 0.7121 - val_loss: 0.8637
# Epoch 19/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 76s 346ms/step - accuracy: 0.7111 - loss: 0.8783 - val_accuracy: 0.7179 - val_loss: 0.8606
# Epoch 20/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 355ms/step - accuracy: 0.7254 - loss: 0.8548 - val_accuracy: 0.7056 - val_loss: 0.8925
# Epoch 21/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 77s 349ms/step - accuracy: 0.7174 - loss: 0.8713 - val_accuracy: 0.7124 - val_loss: 0.8602
# Epoch 22/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 354ms/step - accuracy: 0.7138 - loss: 0.8741 - val_accuracy: 0.7067 - val_loss: 0.9100
# Epoch 23/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 353ms/step - accuracy: 0.7150 - loss: 0.8628 - val_accuracy: 0.7202 - val_loss: 0.8601
# Epoch 24/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 78s 353ms/step - accuracy: 0.7146 - loss: 0.8661 - val_accuracy: 0.7131 - val_loss: 0.8687
# Epoch 25/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 81s 366ms/step - accuracy: 0.7216 - loss: 0.8535 - val_accuracy: 0.7108 - val_loss: 0.8443
# Epoch 26/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 75s 342ms/step - accuracy: 0.7233 - loss: 0.8511 - val_accuracy: 0.7148 - val_loss: 0.8606
# Epoch 27/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 73s 331ms/step - accuracy: 0.7220 - loss: 0.8570 - val_accuracy: 0.7235 - val_loss: 0.8337
# Epoch 28/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 321ms/step - accuracy: 0.7251 - loss: 0.8547 - val_accuracy: 0.7128 - val_loss: 0.8644
# Epoch 29/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 73s 331ms/step - accuracy: 0.7248 - loss: 0.8560 - val_accuracy: 0.7151 - val_loss: 0.8594
# Epoch 30/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 324ms/step - accuracy: 0.7235 - loss: 0.8522 - val_accuracy: 0.7160 - val_loss: 0.9109
# Epoch 31/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 323ms/step - accuracy: 0.7187 - loss: 0.8654 - val_accuracy: 0.6939 - val_loss: 0.9062
# Epoch 32/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 324ms/step - accuracy: 0.7311 - loss: 0.8390 - val_accuracy: 0.7233 - val_loss: 0.8503
# Epoch 33/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 324ms/step - accuracy: 0.7278 - loss: 0.8396 - val_accuracy: 0.7225 - val_loss: 0.8411
# Epoch 34/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 321ms/step - accuracy: 0.7235 - loss: 0.8476 - val_accuracy: 0.7262 - val_loss: 0.8335
# Epoch 35/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 323ms/step - accuracy: 0.7285 - loss: 0.8414 - val_accuracy: 0.6970 - val_loss: 0.8797
# Epoch 36/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 73s 333ms/step - accuracy: 0.7292 - loss: 0.8375 - val_accuracy: 0.7289 - val_loss: 0.8288
# Epoch 37/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 72s 326ms/step - accuracy: 0.7317 - loss: 0.8299 - val_accuracy: 0.7160 - val_loss: 0.8588
# Epoch 38/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 323ms/step - accuracy: 0.7325 - loss: 0.8379 - val_accuracy: 0.7232 - val_loss: 0.8310
# Epoch 39/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 325ms/step - accuracy: 0.7328 - loss: 0.8298 - val_accuracy: 0.7195 - val_loss: 0.8337
# Epoch 40/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 72s 326ms/step - accuracy: 0.7300 - loss: 0.8246 - val_accuracy: 0.7229 - val_loss: 0.8475
# Epoch 41/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 323ms/step - accuracy: 0.7312 - loss: 0.8312 - val_accuracy: 0.7205 - val_loss: 0.8491
# Epoch 42/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 325ms/step - accuracy: 0.7328 - loss: 0.8293 - val_accuracy: 0.7242 - val_loss: 0.8467
# Epoch 43/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 72s 327ms/step - accuracy: 0.7351 - loss: 0.8233 - val_accuracy: 0.7199 - val_loss: 0.8613
# Epoch 44/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 325ms/step - accuracy: 0.7366 - loss: 0.8177 - val_accuracy: 0.7054 - val_loss: 0.8715
# Epoch 45/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 325ms/step - accuracy: 0.7374 - loss: 0.8315 - val_accuracy: 0.7252 - val_loss: 0.8269
# Epoch 46/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 71s 325ms/step - accuracy: 0.7394 - loss: 0.8178 - val_accuracy: 0.7145 - val_loss: 0.8593
# Epoch 47/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 72s 327ms/step - accuracy: 0.7312 - loss: 0.8334 - val_accuracy: 0.7256 - val_loss: 0.8357
# Epoch 48/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 73s 331ms/step - accuracy: 0.7377 - loss: 0.8163 - val_accuracy: 0.7115 - val_loss: 0.8801
# Epoch 49/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 72s 327ms/step - accuracy: 0.7332 - loss: 0.8281 - val_accuracy: 0.7132 - val_loss: 0.8829
# Epoch 50/50
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 73s 331ms/step - accuracy: 0.7345 - loss: 0.8226 - val_accuracy: 0.7131 - val_loss: 0.8591

# %%
import matplotlib.pyplot as plt

ig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Plot Loss
axes[0].plot(history.history['loss'], label='Training Loss')
axes[0].plot(history.history['val_loss'], label='Validation Loss')
axes[0].set_title('Model Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Plot Accuracy
axes[1].plot(history.history['accuracy'], label='Training Accuracy')
axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
axes[1].set_title('Model Accuracy')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
axes[1].legend()

# Menampilkan subplot
plt.tight_layout()
plt.show()

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
